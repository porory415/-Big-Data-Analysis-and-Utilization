# %% [markdown]
# # 빅데이터분석과활용 기말프로젝트
# ##### (박혜빈, 유지원, 윤조현)
#
# ## 주제:
#
# 0. 개요
# 1. Library & Data Import
# 2. 데이터 업로드
# 3. EDA
# #### -classification-
# 4. 데이터 전처리
# - 4-1. stemmer
# - 4.2 Bag of Words : 문장별 단어 벡터 만들기
# - 4.3 Train : Test 로 나누기
# 5. 모델링
# - 5.1 Naive Baye's Classifier(MultinomialNB)
# - 5.2 Random Forest Classifier
# - 5.3 Support Vector Machine
# #### -regression-
# 6. 데이터 파악 (EDA: 탐색적 데이터 분석)
# - 6-1. 데이터셋 기본 정보 파악
# - 6-2. 종속 변수(목표 변수) 탐색
# - 6-3. 설명 변수 탐색
# - 6-4. 설명변수와 종속변수 간의 관계 탐색
# 7. 모델링: 회귀 분석
# - 7-1. 데이터 전처리
# - 7-2. 회귀 모델링
# - 7-3. 모델 해석
# - 7-4. 모델 예측 결과 및 성능 평가

# %%
import yfinance as yf
import pandas as pd

# %%
bitprice = yf.download('BTC-USD', start = '2020-01-01')
bitprice
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2019-12-31   7294.438965   7335.290039   7169.777832   7193.599121
# 2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# ...                  ...           ...           ...           ...
# 2021-11-10  66953.335938  68789.625000  63208.113281  64995.230469
# 2021-11-11  64978.890625  65579.015625  64180.488281  64949.960938
# 2021-11-12  64863.980469  65460.816406  62333.914062  64155.941406
# 2021-11-13  64158.121094  64915.675781  63303.734375  64469.527344
# 2021-11-14  64500.128906  65285.769531  64427.464844  64675.437500
#
#                Adj Close       Volume
# Date
# 2019-12-31   7193.599121  21167946112
# ...
