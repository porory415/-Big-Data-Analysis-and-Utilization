# %%
 import pandas as pd

# %%
csv_test = pd.read_csv('Bitcoin_tweets.csv')

# %%
csv_test.tail(50)
# Out:
#                                  user_name            user_location  \
# 2010674            Crypto Price Prediction     West Hattiesburg, MS
# 2010675                       ThirdBrainFx   Lausanne (Switzerland)
# 2010676  Cryptocurrency prices (real-time)                      NaN
# 2010677            Crypto Price Prediction     West Hattiesburg, MS
# 2010678                            ErolBas                      NaN
# 2010679                 Investor in Turkey                      NaN
# 2010680                        k_mekto_925                      NaN
# 2010681                      Volume Alerts              Seattle, WA
# 2010682                       Randy Barnes                      NaN
# 2010683               Crypto Koryo Signals                      NaN
# 2010684                  Cryptocoin Master                      NaN
# 2010685                   Niklas Feurstein                  Austria
# 2010686     Crypto Blockchain Domain Names          🌎 www.888.house
# ...
