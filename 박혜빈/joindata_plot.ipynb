# %%
import pandas as pd ### 데이터 분석을 하기 위한 파이썬 라이브러리
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("join_complete.csv")

# %%
df.head(3)
# Out:
#    Unnamed: 0        date  subjectivity  polarity        Date          Open  \
# 0           0  2021-02-05      0.243801  0.084413  2021-02-05  36931.546875
# 1           1  2021-02-06      0.257014  0.097354  2021-02-06  38138.386719
# 2           2  2021-02-07      0.326438  0.144448  2021-02-07  39250.191406
#
#            High           Low         Close     Adj Close       Volume
# 0  38225.906250  36658.761719  38144.308594  38144.308594  58598066402
# 1  40846.546875  38138.386719  39266.011719  39266.011719  71326033653
# 2  39621.835938  37446.152344  38903.441406  38903.441406  65500641143

# %%
df.shape
# Out:
# (92, 11)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# date            0
# subjectivity    0
# polarity        0
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0  subjectivity   polarity          Open          High  \
# count    92.00000     92.000000  92.000000     92.000000     92.000000
# mean     45.50000      0.321563   0.133929  47159.392196  48443.249023
# std      26.70206      0.043734   0.035971  10717.035922  10691.054809
# min       0.00000      0.219152   0.072422  29796.285156  31006.187500
# 25%      22.75000      0.293310   0.096733  38194.595703  39737.722656
# 50%      45.50000      0.333731   0.140163  46871.541016  48000.910156
# 75%      68.25000      0.351317   0.162922  57912.541016  58436.839844
# max      91.00000      0.432971   0.205167  66002.234375  66930.390625
#
#                 Low         Close     Adj Close        Volume
# count     92.000000     92.000000     92.000000  9.200000e+01
# mean   45701.748726  47249.746264  47249.746264  4.602204e+10
# std    10475.109649  10492.647347  10492.647347  1.929738e+10
# min    28893.621094  29807.347656  29807.347656  1.878799e+10
# ...

# %%
df['Adj Close'].describe()
# Out:
# count       92.000000
# mean     47249.746264
# std      10492.647347
# min      29807.347656
# 25%      38428.282227
# 50%      46829.898438
# 75%      57450.347656
# max      65992.835938
# Name: Adj Close, dtype: float64

# %%
df['Adj Close'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(df['Adj Close'])
plt.show()

# %%
sns.scatterplot(data=df, x='polarity', y='Adj Close', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
sns.scatterplot(data=df, x='Volume', y='Adj Close', markers='o', color='blue', alpha=0.6)
plt.title('Scatter Plot')
plt.show()

# %%
fig = plt.figure(figsize = (12, 20))
sns.boxplot(x='Adj Close', y='date', data=df)
# Out:
# <AxesSubplot:xlabel='Adj Close', ylabel='date'>

# %%
fig = plt.figure(figsize = (12, 20))
sns.boxplot(x='polarity', y='date', data=df)
# Out:
# <AxesSubplot:xlabel='polarity', ylabel='date'>
