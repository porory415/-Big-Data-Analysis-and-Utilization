# %%
from tqdm import tqdm
import time
import progressbar
import pandas as pd

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
bit_senti2 = pd.read_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\bit_senti2(onlyDate).csv", index_col = 0)
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
bit_senti2
# Out:
#                         date                                 user_name  \
# 0        2021-02-10 23:59:04                             DeSota Wilson
# 1        2021-02-10 23:58:48                                  CryptoND
# 2        2021-02-10 23:54:33                      Crypto is the future
# 3        2021-02-10 23:54:06  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# 4        2021-02-10 23:53:30                       ZerrBenz™ ⚔ ✪ 20732
# ...                      ...                                       ...
# 1734667  2021-11-12 20:27:16                                 JomCRYPTO
# 1734668  2021-11-12 20:27:15                                       Ali
# 1734669  2021-11-12 20:27:08                                  Muhammed
# 1734670  2021-11-12 20:27:08                    Francesco Santoro $VET
# 1734671  2021-11-12 20:27:05                                     GROND
#
#                                           user_description  user_followers  \
# ...

# %%
cnt =0
for j in tqdm(range(bit_senti2.shape[0])):
    for i in range(bit_senti2.shape[0]):
        cnt+=1
        sent = bit_senti2['cleaned_tweets'][i]
        vs = analyzer.polarity_scores(sent)
        time.sleep(0.2)
        print("{:-<60}  {}".format(sent,  str(vs)))
        time.sleep(0.2)
print(cnt)
# Out:
#   0%|                                                                                      | 0/1734672 [00:00<?, ?it/s]
# Blue Ridge Bank share halted NYSE ATM announcement----------  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.296}
# Today Take friend expe--------------------------------------  {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4939}
# BTC A big chance billion Price------------------------------  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.25}
# This network secured node today Soon biggest bear recognise big fail  {'neg': 0.23, 'neu': 0.592, 'pos': 0.178, 'compound': -0.2023}
# Trade Enjoy Trading fee Sign link---------------------------  {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compound': 0.4939}
# lt fire amp man gt------------------------------------------  {'neg': 0.32, 'neu': 0.4, 'pos': 0.28, 'compound': -0.0772}
# RSR I know told guy target know-----------------------------  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ...
