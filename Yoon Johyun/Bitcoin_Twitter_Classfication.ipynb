# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
#yfinance에서 비트코인 가격 확인
bitprice = yf.download('BTC-USD', start = '2019-01-01')
bitprice
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2018-12-31   3866.839111   3868.742920   3725.867432   3742.700439
# 2019-01-01   3746.713379   3850.913818   3707.231201   3843.520020
# 2019-01-02   3849.216309   3947.981201   3817.409424   3943.409424
# 2019-01-03   3931.048584   3935.685059   3826.222900   3836.741211
# 2019-01-04   3832.040039   3865.934570   3783.853760   3857.717529
# ...                  ...           ...           ...           ...
# 2021-11-17  60139.621094  60823.609375  58515.410156  60368.011719
# 2021-11-18  60360.136719  60948.500000  56550.792969  56942.136719
# 2021-11-19  56896.128906  58351.113281  55705.179688  58119.578125
# 2021-11-20  58115.082031  59859.878906  57469.726562  59697.195312
# 2021-11-21  59689.230469  59897.675781  58641.667969  59812.117188
#
#                Adj Close       Volume
# Date
# 2018-12-31   3742.700439   4661840806
# ...

# %%
#트윗데이터 불러오기
tweets_bit = pd.read_csv(r'C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\Bitcoin_tweets.csv')
tweets_bit
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1,2,3,5,6,7,8,9,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                         user_name    user_location  \
# 0                                   DeSota Wilson      Atlanta, GA
# 1                                        CryptoND              NaN
# 2                                       Tdlmatias  London, England
# 3                            Crypto is the future              NaN
# 4        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
# ...                                           ...              ...
# 1932164                                     Melis              NaN
# 1932165                                  Trần Nam              NaN
# 1932166                            Nguyenducthinh              NaN
# ...

# %% [markdown]
# ## Bitcoin_tweets.csv Data Annotation
#  - user_name
#  - user_location
#  - user_description
#  - user_created
#  - user_followers
#  - user_friends
#  - user_favourites
#  - user_verified
#  - date
#  - text
#  - hashtags
#  - source
#  - is_retweet

# %%
#데이터전처리: 필요없는 열 제거
bit_tweets = tweets_bit.drop(['user_location', 'user_created', 'user_verified', 'source'], axis=1)

# %%
bit_tweets
# Out:
#                                         user_name  \
# 0                                   DeSota Wilson
# 1                                        CryptoND
# 2                                       Tdlmatias
# 3                            Crypto is the future
# 4        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# ...                                           ...
# 1932164                                     Melis
# 1932165                                  Trần Nam
# 1932166                            Nguyenducthinh
# 1932167                             Volume Alerts
# 1932168                                      Medi
#
#                                           user_description  user_followers  \
# 0        Biz Consultant, real estate, fintech, startups...          8534.0
# 1        😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 2        IM Academy : The best #forex, #SelfEducation, ...           128.0
# ...

# %%
#컬럼별 결측치 개수 확인
bit_tweets.isnull().sum()
# Out:
# user_name               29
# user_description    283090
# user_followers       89515
# user_friends         89515
# user_favourites      89515
# date                 89515
# text                 89515
# hashtags            106508
# is_retweet           89763
# dtype: int64

# %%
bit_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1932169 entries, 0 to 1932168
# Data columns (total 9 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_name         object
#  1   user_description  object
#  2   user_followers    float64
#  3   user_friends      object
#  4   user_favourites   object
#  5   date              object
#  6   text              object
#  7   hashtags          object
#  8   is_retweet        object
# dtypes: float64(1), object(8)
# memory usage: 132.7+ MB

# %%
import re
import matplotlib.pyplot as plt
from textblob import TextBlob

# %%
#해쉬태그가 결측치일때 행 삭제
bit_tweets.dropna(subset=['hashtags'], inplace=True)
print(bit_tweets.shape[0])
bit_tweets.head(10)
# Out:
# 1825661
#                                    user_name  \
# 0                              DeSota Wilson
# 1                                   CryptoND
# 3                       Crypto is the future
# 4   Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# 5                        ZerrBenz™ ⚔ ✪ 20732
# 6                                Bitcoin-Bot
# 8                                    Mikcoin
# 9                              DeSota Wilson
# 10     @massumeh18 #RefinedWarrior #Activist
# 13                           One Perspective
#
#                                      user_description  user_followers  \
# 0   Biz Consultant, real estate, fintech, startups...          8534.0
# 1   😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 3   I will post a lot of buying signals for BTC tr...           625.0
# 4   Co-founder @RENJERJerky | Forbes 30Under30 | I...          1249.0
# 5   I'm a cat slave 🐱 Interested in Blockchain · T...           742.0
# ...

# %%
#자연어 처리: 불용어 제거
import nltk
from nltk.stem.wordnet import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
stop_words = nltk.corpus.stopwords.words(['english'])


print(stop_words)   #nltk가 정의한 불용어 출력
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# ...

# %%
from nltk.tokenize import TweetTokenizer
from nltk.stem.wordnet import WordNetLemmatizer

# %%
#표제어 추출
lemm = WordNetLemmatizer()
def cleaning(data):
    #remove urls
    tweet_without_url = re.sub(r'http\S+',' ', data)
    #remove hashtags
    tweet_without_hashtag = re.sub(r'#\w+', ' ', tweet_without_url)

    #3. Remove mentions and characters that not in the English alphabets
    tweet_without_mentions = re.sub(r'@\w+',' ', tweet_without_hashtag)
    precleaned_tweet = re.sub('[^A-Za-z]+', ' ', tweet_without_mentions)

    #2. Tokenize
    tweet_tokens = TweetTokenizer().tokenize(precleaned_tweet)
    
    #3. Remove Puncs
    tokens_without_punc = [w for w in tweet_tokens if w.isalpha()]
    
    #4. Removing Stopwords
    tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]
    
    #5. lemma
    text_cleaned = [lemm.lemmatize(t) for t in tokens_without_sw]
    
    #6. Joining
    return " ".join(text_cleaned)

# %%
bit_tweets['cleaned_tweets'] = bit_tweets['text'].apply(cleaning)
bit_tweets.head()
# Out:
#                                   user_name  \
# 0                             DeSota Wilson
# 1                                  CryptoND
# 3                      Crypto is the future
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# 5                       ZerrBenz™ ⚔ ✪ 20732
#
#                                     user_description  user_followers  \
# 0  Biz Consultant, real estate, fintech, startups...          8534.0
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 3  I will post a lot of buying signals for BTC tr...           625.0
# 4  Co-founder @RENJERJerky | Forbes 30Under30 | I...          1249.0
# 5  I'm a cat slave 🐱 Interested in Blockchain · T...           742.0
#
#   user_friends user_favourites                 date  \
# 0         7605            4838  2021-02-10 23:59:04
# 1         1532           25483  2021-02-10 23:58:48
# 3          129              14  2021-02-10 23:54:33
# 4         1472           10482  2021-02-10 23:54:06
# ...

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity


def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
bit_tweets['subjectivity'] = bit_tweets['cleaned_tweets'].apply(getSubjectivity)
bit_tweets['polarity'] = bit_tweets['cleaned_tweets'].apply(getPolarity)
bit_tweets.head()
# Out:
#                                   user_name  \
# 0                             DeSota Wilson
# 1                                  CryptoND
# 3                      Crypto is the future
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# 5                       ZerrBenz™ ⚔ ✪ 20732
#
#                                     user_description  user_followers  \
# 0  Biz Consultant, real estate, fintech, startups...          8534.0
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 3  I will post a lot of buying signals for BTC tr...           625.0
# 4  Co-founder @RENJERJerky | Forbes 30Under30 | I...          1249.0
# 5  I'm a cat slave 🐱 Interested in Blockchain · T...           742.0
#
#   user_friends user_favourites                 date  \
# 0         7605            4838  2021-02-10 23:59:04
# 1         1532           25483  2021-02-10 23:58:48
# 3          129              14  2021-02-10 23:54:33
# 4         1472           10482  2021-02-10 23:54:06
# ...

# %%
def getSentiment(score):
    if score < 0:
        return 'negative'
    elif score ==0:
        return 'neutral'
    else:
        return 'positive'

# %%
bit_tweets['sentiment'] = bit_tweets['polarity'].apply(getSentiment)
bit_tweets.head()
# Out:
#                                   user_name  \
# 0                             DeSota Wilson
# 1                                  CryptoND
# 3                      Crypto is the future
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# 5                       ZerrBenz™ ⚔ ✪ 20732
#
#                                     user_description  user_followers  \
# 0  Biz Consultant, real estate, fintech, startups...          8534.0
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 3  I will post a lot of buying signals for BTC tr...           625.0
# 4  Co-founder @RENJERJerky | Forbes 30Under30 | I...          1249.0
# 5  I'm a cat slave 🐱 Interested in Blockchain · T...           742.0
#
#   user_friends user_favourites                 date  \
# 0         7605            4838  2021-02-10 23:59:04
# 1         1532           25483  2021-02-10 23:58:48
# 3          129              14  2021-02-10 23:54:33
# 4         1472           10482  2021-02-10 23:54:06
# ...

# %%
#지금까지 결과물 csv로 저장
bit_tweets.to_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\bit_tweets_sentiment.csv", index = False)

# %%
# 확인
bit_senti = pd.read_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\bit_tweets_sentiment.csv")
bit_senti
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                         user_name  \
# 0                                   DeSota Wilson
# 1                                        CryptoND
# 2                            Crypto is the future
# 3        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# 4                             ZerrBenz™ ⚔ ✪ 20732
# ...                                           ...
# 1825656                                     Melis
# 1825657                                  Trần Nam
# 1825658                            Nguyenducthinh
# 1825659                             Volume Alerts
# 1825660                                      Medi
#
#                                           user_description  user_followers  \
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow.keras.layers as Layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, Dropout, Embedding, LSTM, Conv1D, GlobalMaxPooling1D, Bidirectional, SpatialDropout1D
from keras.models import load_model


from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# Encode Categorical Variable
X = bit_senti['cleaned_tweets'].astype(str)
y = pd.get_dummies(bit_senti['sentiment']).values   # 머신러닝 사용을 위해 범주형 -> 수치데이터
num_classes = bit_senti['sentiment'].nunique()    #3

# %%
seed = 101         # fix random seed for reproducibility
np.random.seed(seed)

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=seed)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1460528,) (365133,) (1460528, 3) (365133, 3)

# %%
max_features = 20000
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(X_train))
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
from keras.preprocessing import sequence
max_words = 30
X_train = sequence.pad_sequences(X_train, maxlen=max_words)
X_test = sequence.pad_sequences(X_test, maxlen=max_words)
print(X_train.shape,X_test.shape)
# Out:
# (1460528, 30) (365133, 30)

# %%
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense,Embedding,Conv1D,MaxPooling1D,LSTM
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

batch_size = 128
epochs = 5

max_features = 20000
embed_dim = 100

np.random.seed(seed)
K.clear_session()
model = Sequential()
model.add(Embedding(max_features, embed_dim, input_length=X_train.shape[1]))
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))    
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 30, 100)           2000000
#
#  conv1d (Conv1D)             (None, 30, 32)            9632
#
#  max_pooling1d (MaxPooling1D  (None, 15, 32)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 15, 32)            3104
#
#  max_pooling1d_1 (MaxPooling  (None, 7, 32)            0
#  1D)
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dense (Dense)               (None, 3)                 303
#
# ...
# Total params: 2,066,239
# Trainable params: 2,066,239
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), 
                          epochs=epochs, batch_size=batch_size, verbose=2)
# Out:
# Epoch 1/5
# 11411/11411 - 558s - loss: 0.0558 - accuracy: 0.9825 - val_loss: 0.0303 - val_accuracy: 0.9912 - 558s/epoch - 49ms/step
# Epoch 2/5
# 11411/11411 - 540s - loss: 0.0261 - accuracy: 0.9923 - val_loss: 0.0246 - val_accuracy: 0.9928 - 540s/epoch - 47ms/step
# Epoch 3/5

# %%
# predict class with test set
y_pred_test =  np.argmax(model.predict(X_test), axis=1)
print('Accuracy:\t{:0.1f}%'.format(accuracy_score(np.argmax(y_test,axis=1),y_pred_test)*100))
print(classification_report(np.argmax(y_test,axis=1), y_pred_test))
