# %%
import pandas as pd
import numpy as np

# %%
bit_senti = pd.read_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\bit_tweets_class.csv")
bit_senti
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                         user_name  \
# 0                                   DeSota Wilson
# 1                                        CryptoND
# 2                            Crypto is the future
# 3        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# 4                             ZerrBenz™ ⚔ ✪ 20732
# ...                                           ...
# 1734667                                 JomCRYPTO
# 1734668                                       Ali
# 1734669                                  Muhammed
# 1734670                    Francesco Santoro $VET
# 1734671                                     GROND
#
#                                           user_description  user_followers  \
# 0        Biz Consultant, real estate, fintech, startups...          8534.0
# 1        😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 2        I will post a lot of buying signals for BTC tr...           625.0
# 3        Co-founder @RENJERJerky | Forbes 30Under30 | I...          1249.0
# 4        I'm a cat slave 🐱 Interested in Blockchain · T...           742.0
# ...                                                    ...             ...
# 1734667                                          Developer             5.0
# 1734668                                                NaN            80.0
# 1734669                                                NaN            34.0
# 1734670  Investitore #BNB , #CRO e  #VET appassionato d...            76.0
# 1734671  Investor / Misantrophe / Fudie\n\nPyramid sche...            17.0
#
#         user_friends user_favourites                 date  \
# 0               7605            4838  2021-02-10 23:59:04
# 1               1532           25483  2021-02-10 23:58:48
# 2                129              14  2021-02-10 23:54:33
# 3               1472           10482  2021-02-10 23:54:06
# 4                716            2444  2021-02-10 23:53:30
# ...              ...             ...                  ...
# 1734667           41             394  2021-11-12 20:27:16
# 1734668          217             191  2021-11-12 20:27:15
# 1734669           81            3695  2021-11-12 20:27:08
# 1734670          354            1011  2021-11-12 20:27:08
# 1734671           41             594  2021-11-12 20:27:05
#
#                                                       text  \
# 0        Blue Ridge Bank shares halted by NYSE after #b...
# 1        😎 Today, that's this #Thursday, we will do a "...
# 2        $BTC A big chance in a billion! Price: \487264...
# 3        This network is secured by 9 508 nodes as of t...
# 4        💹 Trade #Crypto on #Binance \n\n📌 Enjoy #Cashb...
# ...                                                    ...
# 1734667  @WatcherGuru #Btc\n#ETH \n#LTC \n#COSMOS \n#St...
# 1734668  @TheBitcoinConf @priceoftomorrow @addyinvest @...
# 1734669  @Heatherfernsby #pitbulltoken will be the doge...
# 1734670  I am changing the way I invest. In the wallet ...
# 1734671  @LucaLand97 It is absolutely unbelievable. And...
#
#                                                   hashtags is_retweet  \
# 0                                              ['bitcoin']      False
# 1                ['Thursday', 'Btc', 'wallet', 'security']      False
# 2                       ['Bitcoin', 'FX', 'BTC', 'crypto']      False
# 3                                                  ['BTC']      False
# 4                        ['Crypto', 'Binance', 'Cashback']      False
# ...                                                    ...        ...
# 1734667  ['Btc', 'ETH', 'LTC', 'COSMOS', 'Stellar', 'Do...      False
# 1734668  ['shib', 'shiba', 'shiba_army', 'shibaw', 'shi...      False
# 1734669  ['pitbulltoken', 'pitbull', 'PitbullToken100x'...      False
# 1734670                              ['VET', 'btc', 'BNB']      False
# 1734671                                            ['BTC']      False
#
#                                             cleaned_tweets  subjectivity  \
# 0        Blue Ridge Bank share halted NYSE ATM announce...      0.100000
# 1                                   Today Take friend expe      0.000000
# 2                           BTC A big chance billion Price      0.100000
# 3        This network secured node today Soon biggest b...      0.200000
# 4                        Trade Enjoy Trading fee Sign link      0.500000
# ...                                                    ...           ...
# 1734667                                               Dogs      0.000000
# 1734668  Calm We go moon soon The new Shiba It x Unveil...      0.602273
# 1734669                 dogecoin future huge investor base      0.675000
# 1734670  I changing way I invest In wallet The rest fun...      0.000000
# 1734671  It absolutely unbelievable And price hardly re...      0.770833
#
#          polarity sentiment
# 0        0.000000   neutral
# 1        0.000000   neutral
# 2        0.000000   neutral
# 3       -0.250000  negative
# 4        0.400000  positive
# ...           ...       ...
# 1734667  0.000000   neutral
# 1734668  0.218182  positive
# 1734669 -0.133333  negative
# 1734670  0.000000   neutral
# 1734671 -0.270833  negative
#
# [1734672 rows x 13 columns]

# %%
#column순서 변경
bit_senti = bit_senti[['date', 'user_name', 'user_description', 'user_followers', 'user_friends',
       'user_favourites', 'text', 'hashtags', 'is_retweet',
       'cleaned_tweets', 'subjectivity', 'polarity', 'sentiment']]

# %%
g_senti = bit_senti[['subjectivity','polarity','date']].groupby(bit_senti['date'])
g_senti.head()
# Out:
#          subjectivity  polarity                 date
# 0            0.100000  0.000000  2021-02-10 23:59:04
# 1            0.000000  0.000000  2021-02-10 23:58:48
# 2            0.100000  0.000000  2021-02-10 23:54:33
# 3            0.200000 -0.250000  2021-02-10 23:54:06
# 4            0.500000  0.400000  2021-02-10 23:53:30
# ...               ...       ...                  ...
# 1734667      0.000000  0.000000  2021-11-12 20:27:16
# 1734668      0.602273  0.218182  2021-11-12 20:27:15
# 1734669      0.675000 -0.133333  2021-11-12 20:27:08
# 1734670      0.000000  0.000000  2021-11-12 20:27:08
# 1734671      0.770833 -0.270833  2021-11-12 20:27:05
#
# [1725888 rows x 3 columns]

# %%
#슬라이싱하여 추출할 날짜 텍스트 확인
date = bit_senti['date'][3][:10]
date
# Out:
# '2021-02-10'

# %%
dtList = []
for i in range(bit_senti.shape[0]):
    date = bit_senti['date'][i][:10]
    dtList.append(date)
bit_senti['only_date'] = dtList

bit_senti.head()
# Out:
#                   date                                 user_name  \
# 0  2021-02-10 23:59:04                             DeSota Wilson
# 1  2021-02-10 23:58:48                                  CryptoND
# 2  2021-02-10 23:54:33                      Crypto is the future
# 3  2021-02-10 23:54:06  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# 4  2021-02-10 23:53:30                       ZerrBenz™ ⚔ ✪ 20732
#
#                                     user_description  user_followers  \
# 0  Biz Consultant, real estate, fintech, startups...          8534.0
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 2  I will post a lot of buying signals for BTC tr...           625.0
# 3  Co-founder @RENJERJerky | Forbes 30Under30 | I...          1249.0
# 4  I'm a cat slave 🐱 Interested in Blockchain · T...           742.0
#
#   user_friends user_favourites  \
# 0         7605            4838
# 1         1532           25483
# 2          129              14
# 3         1472           10482
# 4          716            2444
#
#                                                 text  \
# 0  Blue Ridge Bank shares halted by NYSE after #b...
# 1  😎 Today, that's this #Thursday, we will do a "...
# 2  $BTC A big chance in a billion! Price: \487264...
# 3  This network is secured by 9 508 nodes as of t...
# 4  💹 Trade #Crypto on #Binance \n\n📌 Enjoy #Cashb...
#
#                                     hashtags is_retweet  \
# 0                                ['bitcoin']      False
# 1  ['Thursday', 'Btc', 'wallet', 'security']      False
# 2         ['Bitcoin', 'FX', 'BTC', 'crypto']      False
# 3                                    ['BTC']      False
# 4          ['Crypto', 'Binance', 'Cashback']      False
#
#                                       cleaned_tweets  subjectivity  polarity  \
# 0  Blue Ridge Bank share halted NYSE ATM announce...           0.1      0.00
# 1                             Today Take friend expe           0.0      0.00
# 2                     BTC A big chance billion Price           0.1      0.00
# 3  This network secured node today Soon biggest b...           0.2     -0.25
# 4                  Trade Enjoy Trading fee Sign link           0.5      0.40
#
#   sentiment   only_date
# 0   neutral  2021-02-10
# 1   neutral  2021-02-10
# 2   neutral  2021-02-10
# 3  negative  2021-02-10
# 4  positive  2021-02-10

# %%
from datetime import datetime, date
import time

# %%
#only_date 컬럼의 데이터타입을 str -> datetime.date로 바꾸기
for i in range(bit_senti.shape[0]):
#     str_date = bit_senti['only_date'][i]
    try:
        bit_senti['datetime'] =  pd.to_datetime(bit_senti['only_date'], format = '%Y-%m-%d', errors = 'raise')
    except:
        pass

bit_senti.head()

# %%
#datetime 변환 확인
print(type(bit_senti['only_date'][10]))
# Out:
# <class 'str'>

# %%
# 지금까지의 데이터 전처리 csv로 저장
bit_senti.to_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\bit_forJoin_try2.csv")
