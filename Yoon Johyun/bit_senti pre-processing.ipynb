# %%
import pandas as pd
import numpy as np

# %%
bit_senti = pd.read_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\bit_tweets_class.csv")
bit_senti.head()
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                   user_name  \
# 0                             DeSota Wilson
# 1                                  CryptoND
# 2                      Crypto is the future
# 3  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# 4                       ZerrBenz™ ⚔ ✪ 20732
#
#                                     user_description  user_followers  \
# 0  Biz Consultant, real estate, fintech, startups...          8534.0
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...          6769.0
# 2  I will post a lot of buying signals for BTC tr...           625.0
# 3  Co-founder @RENJERJerky | Forbes 30Under30 | I...          1249.0
# 4  I'm a cat slave 🐱 Interested in Blockchain · T...           742.0
#
# ...

# %%
#column순서 변경
bit_senti = bit_senti[['date', 'user_name', 'user_description', 'user_followers', 'user_friends',
       'user_favourites', 'text', 'hashtags', 'is_retweet',
       'cleaned_tweets', 'subjectivity', 'polarity', 'sentiment']]

# %%
#슬라이싱하여 추출할 날짜 텍스트 확인
date = bit_senti['date'][3][:10]
date
# Out:
# '2021-02-10'

# %%
dtList = []
for i in range(bit_senti.shape[0]):
    date = bit_senti['date'][i][:10]
    dtList.append(date)
    
bit_senti['only_date'] = dtList

bit_senti.tail()
# Out:
#                         date               user_name  \
# 1734667  2021-11-12 20:27:16               JomCRYPTO
# 1734668  2021-11-12 20:27:15                     Ali
# 1734669  2021-11-12 20:27:08                Muhammed
# 1734670  2021-11-12 20:27:08  Francesco Santoro $VET
# 1734671  2021-11-12 20:27:05                   GROND
#
#                                           user_description  user_followers  \
# 1734667                                          Developer             5.0
# 1734668                                                NaN            80.0
# 1734669                                                NaN            34.0
# 1734670  Investitore #BNB , #CRO e  #VET appassionato d...            76.0
# 1734671  Investor / Misantrophe / Fudie\n\nPyramid sche...            17.0
#
#         user_friends user_favourites  \
# 1734667           41             394
# 1734668          217             191
# 1734669           81            3695
# 1734670          354            1011
# ...

# %%
bit_senti2 = bit_senti
bit_senti2.columns
# Out:
# Index(['date', 'user_name', 'user_description', 'user_followers',
#        'user_friends', 'user_favourites', 'text', 'hashtags', 'is_retweet',
#        'cleaned_tweets', 'subjectivity', 'polarity', 'sentiment', 'only_date'],
#       dtype='object')

# %%
bit_senti2.to_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\bit_senti2(onlyDate).csv")

# %%
import pandas as pd
import numpy as np

# %%
bit_senti2 = pd.read_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\bit_senti2(onlyDate).csv")
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5,6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
aaa = bit_senti2[['subjectivity','polarity','only_date']]
print(aaa.columns)
aaa.head()
# Out:
# Index(['subjectivity', 'polarity', 'only_date'], dtype='object')
#    subjectivity  polarity   only_date
# 0           0.1      0.00  2021-02-10
# 1           0.0      0.00  2021-02-10
# 2           0.1      0.00  2021-02-10
# 3           0.2     -0.25  2021-02-10
# 4           0.5      0.40  2021-02-10

# %%
aa= aaa.groupby(['only_date']).mean()
print(aa.shape)
aa
# Out:
# (100, 2)
#             subjectivity  polarity
# only_date
# 2021-02-05      0.243801  0.084413
# 2021-02-06      0.257014  0.097354
# 2021-02-07      0.326438  0.144448
# 2021-02-08      0.249640  0.091342
# 2021-02-09      0.245403  0.092980
# ...                  ...       ...
# ['YieldFar      0.000000  0.000000
# ['bitcoin'      0.000000  0.000000
# ['btc']         0.000000  0.000000
# ['cryptocu      0.000000  0.000000
# ['cryptotr      0.000000  0.000000
#
# [100 rows x 2 columns]

# %%
print(type(bit_senti2['only_date'][2]))
# Out:
# <class 'str'>

# %%
aa.index.name = 'date'
aa.reset_index(drop = False, inplace = True)
aa
# Out:
#           date  subjectivity  polarity
# 0   2021-02-05      0.243801  0.084413
# 1   2021-02-06      0.257014  0.097354
# 2   2021-02-07      0.326438  0.144448
# 3   2021-02-08      0.249640  0.091342
# 4   2021-02-09      0.245403  0.092980
# ..         ...           ...       ...
# 95  ['YieldFar      0.000000  0.000000
# 96  ['bitcoin'      0.000000  0.000000
# 97     ['btc']      0.000000  0.000000
# 98  ['cryptocu      0.000000  0.000000
# 99  ['cryptotr      0.000000  0.000000
#
# [100 rows x 3 columns]

# %%
import re  #정규표현식

# %%
from tqdm import tqdm
import progressbar

for i in tqdm(range(80, 100)):
    dt_regex = re.compile('[a-z]', re.I)
    valid = dt_regex.search(aa['date'][i])
    if valid:
        aa.drop(index =i ,axis =0, inplace = True)
    else:
        pass

print(aa)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 1981.53it/s]
#           date  subjectivity  polarity
# 0   2021-02-05      0.243801  0.084413
# 1   2021-02-06      0.257014  0.097354
# 2   2021-02-07      0.326438  0.144448
# 3   2021-02-08      0.249640  0.091342
# 4   2021-02-09      0.245403  0.092980
# ..         ...           ...       ...
# 87  2021-11-04      0.349635  0.169745
# 88  2021-11-05      0.355022  0.165330
# 89  2021-11-06      0.351870  0.167605
# 90  2021-11-11      0.333200  0.148472
# 91  2021-11-12      0.347929  0.158708
#
# [92 rows x 3 columns]

# %%
aa
# Out:
#           date  subjectivity  polarity
# 0   2021-02-05      0.243801  0.084413
# 1   2021-02-06      0.257014  0.097354
# 2   2021-02-07      0.326438  0.144448
# 3   2021-02-08      0.249640  0.091342
# 4   2021-02-09      0.245403  0.092980
# ..         ...           ...       ...
# 87  2021-11-04      0.349635  0.169745
# 88  2021-11-05      0.355022  0.165330
# 89  2021-11-06      0.351870  0.167605
# 90  2021-11-11      0.333200  0.148472
# 91  2021-11-12      0.347929  0.158708
#
# [92 rows x 3 columns]

# %%
aa.to_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\3col_1.csv")
