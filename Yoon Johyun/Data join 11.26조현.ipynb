# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime, date
import time
from tqdm import tqdm
import progressbar

# %%
bit_forjoin = pd.read_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\bit_class_forJoin.csv")  #bit_senti2와 동일할듯
# bit_forjoin
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,5,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#datetime 변환 확인
print(type(bit_forjoin['only_date'][10]))
# Out:
# <class 'str'>

# %%
np.set_printoptions(threshold=np.inf, linewidth=np.inf)

# %%
#날짜 고유값 확인
a = bit_forjoin['only_date'].unique()
a.sort()
for i in tqdm(range(1)):
    print(a)
print(len(a))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 970.01it/s]
# ...

# %% [markdown]
# ## 여기서부터 시작

# %%
import pandas as pd
import numpy as np

# %%
cleantwitt = pd.read_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\3col_1.csv", index_col =0)
cleantwitt
# Out:
#           date  subjectivity  polarity
# 0   2021-02-05      0.243801  0.084413
# 1   2021-02-06      0.257014  0.097354
# 2   2021-02-07      0.326438  0.144448
# 3   2021-02-08      0.249640  0.091342
# 4   2021-02-09      0.245403  0.092980
# ..         ...           ...       ...
# 87  2021-11-04      0.349635  0.169745
# 88  2021-11-05      0.355022  0.165330
# 89  2021-11-06      0.351870  0.167605
# 90  2021-11-11      0.333200  0.148472
# 91  2021-11-12      0.347929  0.158708
#
# [92 rows x 3 columns]

# %%
print(cleantwitt['date'][0])
print(cleantwitt['date'][20])
# Out:
# 2021-02-05
# 2021-04-10

# %%
for i in range(92):
    str_date = cleantwitt['date'][i]
    cleantwitt['date'][i] = pd.to_datetime(str_date, format = '%Y-%m-%d').date()
    
cleantwitt
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_2004/3104185088.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleantwitt['date'][i] = pd.to_datetime(str_date, format = '%Y-%m-%d').date()
#           date  subjectivity  polarity
# 0   2021-02-05      0.243801  0.084413
# 1   2021-02-06      0.257014  0.097354
# 2   2021-02-07      0.326438  0.144448
# 3   2021-02-08      0.249640  0.091342
# 4   2021-02-09      0.245403  0.092980
# ..         ...           ...       ...
# 87  2021-11-04      0.349635  0.169745
# 88  2021-11-05      0.355022  0.165330
# 89  2021-11-06      0.351870  0.167605
# 90  2021-11-11      0.333200  0.148472
# 91  2021-11-12      0.347929  0.158708
#
# [92 rows x 3 columns]

# %%
#변환 타입 확인
cleantwitt2 = cleantwitt
print(type(str_date))
print(type(cleantwitt2['date'][10]))
# Out:
# <class 'str'>
# <class 'datetime.date'>

# %%
cleantwitt2['date'] = cleantwitt2['date'].astype(str)

# %%
import yfinance as yf

# %%
bitprice = yf.download('BTC-USD', start ='2021-02-05', end ='2021-11-13')
bitprice.reset_index(drop = False, inplace = True)
print(type(bitprice['Date'][4]))
bitprice
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#           Date          Open          High           Low         Close  \
# 0   2021-02-04  37475.105469  38592.175781  36317.500000  36926.066406
# 1   2021-02-05  36931.546875  38225.906250  36658.761719  38144.308594
# 2   2021-02-06  38138.386719  40846.546875  38138.386719  39266.011719
# 3   2021-02-07  39250.191406  39621.835938  37446.152344  38903.441406
# 4   2021-02-08  38886.828125  46203.929688  38076.324219  46196.464844
# ..         ...           ...           ...           ...           ...
# 277 2021-11-08  63344.066406  67673.742188  63344.066406  67566.828125
# 278 2021-11-09  67549.734375  68530.335938  66382.062500  66971.828125
# 279 2021-11-10  66953.335938  68789.625000  63208.113281  64995.230469
# 280 2021-11-11  64978.890625  65579.015625  64180.488281  64949.960938
# ...

# %%
bitprice2 = bitprice
bitprice2['Date'] =bitprice2.Date.astype(str)
print(bitprice2['Date'])
bitprice2
# Out:
# 0      2021-02-04
# 1      2021-02-05
# 2      2021-02-06
# 3      2021-02-07
# 4      2021-02-08
#           ...
# 277    2021-11-08
# 278    2021-11-09
# 279    2021-11-10
# 280    2021-11-11
# 281    2021-11-12
# Name: Date, Length: 282, dtype: object
#            Date          Open          High           Low         Close  \
# 0    2021-02-04  37475.105469  38592.175781  36317.500000  36926.066406
# 1    2021-02-05  36931.546875  38225.906250  36658.761719  38144.308594
# 2    2021-02-06  38138.386719  40846.546875  38138.386719  39266.011719
# 3    2021-02-07  39250.191406  39621.835938  37446.152344  38903.441406
# 4    2021-02-08  38886.828125  46203.929688  38076.324219  46196.464844
# ..          ...           ...           ...           ...           ...
# 277  2021-11-08  63344.066406  67673.742188  63344.066406  67566.828125
# 278  2021-11-09  67549.734375  68530.335938  66382.062500  66971.828125
# 279  2021-11-10  66953.335938  68789.625000  63208.113281  64995.230469
# ...

# %%
#되긴되는데...이럴거면 트윗데이터 date를 뭐하러 datetime으로 바꾸느라...눙물..
leftJoin = pd.merge(cleantwitt2, bitprice2, left_on = 'date', right_on ='Date', how = 'left')
leftJoin
# Out:
#           date  subjectivity  polarity        Date          Open  \
# 0   2021-02-05      0.243801  0.084413  2021-02-05  36931.546875
# 1   2021-02-06      0.257014  0.097354  2021-02-06  38138.386719
# 2   2021-02-07      0.326438  0.144448  2021-02-07  39250.191406
# 3   2021-02-08      0.249640  0.091342  2021-02-08  38886.828125
# 4   2021-02-09      0.245403  0.092980  2021-02-09  46184.992188
# ..         ...           ...       ...         ...           ...
# 87  2021-11-04      0.349635  0.169745  2021-11-04  62941.804688
# 88  2021-11-05      0.355022  0.165330  2021-11-05  61460.078125
# 89  2021-11-06      0.351870  0.167605  2021-11-06  61068.875000
# 90  2021-11-11      0.333200  0.148472  2021-11-11  64978.890625
# 91  2021-11-12      0.347929  0.158708  2021-11-12  64863.980469
#
#             High           Low         Close     Adj Close        Volume
# 0   38225.906250  36658.761719  38144.308594  38144.308594   58598066402
# ...

# %%
leftJoin.to_csv(r"C:\Users\Lenovo\OneDrive\빅데이터분석&활용팀플\csv outputs\join_complete.csv")
